# %%
import pandas as pd
import numpy as np
import nltk
import re
from string import punctuation
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

def load_data(path):
    train = pd.read_csv(path+'/train.csv')
    test = pd.read_csv(path+'/test.csv')
    y = train['is_duplicate']
    return train, test


def fill_missing_values(train, test):
    # Check for any null values
    print(train.isnull().sum())
    print(test.isnull().sum())
    
    # We find 2 null values in train and test both
    # Replace them with an 'empty' string
    train = train.fillna('empty')
    test = test.fillna('empty')
    return train, test

    
def clean_text(text, remove_stopwords=True, stemming=False):
    
    
     # Clean the text
    text = re.sub(r"[^A-Za-z0-9]", " ", text)
    text = re.sub(r"what's", "", text)
    text = re.sub(r"What's", "", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"I'm", "I am", text)
    text = re.sub(r" m ", " am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"60k", " 60000 ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e-mail", "email", text)
    text = re.sub(r"\s{2,}", " ", text)
    text = re.sub(r"quikly", "quickly", text)
    text = re.sub(r" usa ", " America ", text)
    text = re.sub(r" USA ", " America ", text)
    text = re.sub(r" u s ", " America ", text)
    text = re.sub(r" uk ", " England ", text)
    text = re.sub(r" UK ", " England ", text)
    text = re.sub(r"india", "India", text)
    text = re.sub(r"switzerland", "Switzerland", text)
    text = re.sub(r"china", "China", text)
    text = re.sub(r"chinese", "Chinese", text) 
    text = re.sub(r"imrovement", "improvement", text)
    text = re.sub(r"intially", "initially", text)
    text = re.sub(r"quora", "Quora", text)
    text = re.sub(r" dms ", "direct messages ", text)  
    text = re.sub(r"demonitization", "demonetization", text) 
    text = re.sub(r"actived", "active", text)
    text = re.sub(r"kms", " kilometers ", text)
    text = re.sub(r"KMs", " kilometers ", text)
    text = re.sub(r" cs ", " computer science ", text) 
    text = re.sub(r" upvotes ", " up votes ", text)
    text = re.sub(r" iPhone ", " phone ", text)
    text = re.sub(r"\0rs ", " rs ", text) 
    text = re.sub(r"calender", "calendar", text)
    text = re.sub(r"ios", "operating system", text)
    text = re.sub(r"gps", "GPS", text)
    text = re.sub(r"gst", "GST", text)
    text = re.sub(r"programing", "programming", text)
    text = re.sub(r"bestfriend", "best friend", text)
    text = re.sub(r"dna", "DNA", text)
    text = re.sub(r"III", "3", text) 
    text = re.sub(r"the US", "America", text)
    text = re.sub(r"Astrology", "astrology", text)
    text = re.sub(r"Method", "method", text)
    text = re.sub(r"Find", "find", text) 
    text = re.sub(r"banglore", "Banglore", text)
    text = re.sub(r" J K ", " JK ", text)
    
    # Remove punctuation from text
    text = ''.join([c for c in text if c not in punctuation])
    
    # Remove stop words
    if remove_stopwords:
        text = text.split()
        text = [w for w in text if not w in stop_words]
        text = " ".join(text)
    
    # Shorten words to their stems
    if stemming:
        text = text.split()
        stemmer = PorterStemmer('english')
        stemmed_words = [stemmer.stem(word) for word in text]
        text = " ".join(stemmed_words)
    
    # Return a list of words
    return(text)


train, test = load_data('../data')
train, test = fill_missing_values(train, test)

print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       2
# is_duplicate    0
# dtype: int64
# test_id      0
# question1    2
# question2    4
# dtype: int64
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64
# test_id      0
# question1    0
# question2    0
# dtype: int64

# %%
stop_words = ['the','a','an','and','but','if','or','because','as','what','which','this','that','these','those','then',
              'just','so','than','such','both','through','about','for','is','of','while','during','to','What','Which',
              'Is','If','While','This']

# %%
def process_questions(question_list, questions, question_list_name, dataframe):
    '''transform questions and display progress'''
    for idx, question in enumerate(questions):
        question_list.append(clean_text(question, remove_stopwords=True, stemming=True))
        if len(question_list) % 100000 == 0:
            progress = len(question_list)/len(dataframe) * 100
            print("{} is {}% complete.".format(question_list_name, round(progress, 1)))

# %%
train_question2 = []
process_questions(train_question2, train.question2, 'train_question2', train)
# Out:
# train_question2 is 0.0% complete.
# train_question2 is 0.0% complete.
# train_question2 is 0.0% complete.
# train_question2 is 0.0% complete.

# %%
train_question1 = []
process_questions(train_question1, train.question1, 'train_question1', train)
# Out:
# train_question1 is 0.0% complete.
# train_question1 is 0.0% complete.
# train_question1 is 0.0% complete.
# train_question1 is 0.0% complete.

# %%
test_question1 = []
process_questions(test_question1, test.question1, 'test_question1', test)

test_question2 = []
process_questions(test_question2, test.question2, 'test_question2', test)
# Out:
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question1 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.
# test_question2 is 0.0% complete.

# %%
# append these clean questions back to the original dataframes

train_q1_clean = pd.Series(train_question1)
train_q2_clean = pd.Series(train_question2)
test_q1_clean = pd.Series(test_question1)
test_q2_clean = pd.Series(test_question2)

train = pd.concat([train, train_q1_clean], axis = 1)
train = pd.concat([train, train_q2_clean], axis = 1)

test = pd.concat([test, test_q1_clean], axis = 1)
test = pd.concat([test, test_q2_clean], axis = 1)

# %%
print train
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# 5            5      11      12
# 6            6      13      14
# 7            7      15      16
# 8            8      17      18
# 9            9      19      20
# 10          10      21      22
# 11          11      23      24
# 12          12      25      26
# 13          13      27      28
# 14          14      29      30
# 15          15      31      32
# 16          16      33      34
# 17          17      35      36
# 18          18      37      38
# 19          19      39      40
# 20          20      41      42
# 21          21      43      44
# 22          22      45      46
# 23          23      47      48
# 24          24      49      50
# 25          25      51      52
# 26          26      53      54
# 27          27      55      56
# 28          28      57      58
# 29          29      59      60
# ...        ...     ...     ...
# 404260  404260  182494     691
# 404261  404261  281150  124172
# 404262  404262  537905  466328
# 404263  404263  375195  537906
# 404264  404264  537907  537908
# 404265  404265   25994   16064
# 404266  404266  155813  146284
# 404267  404267   20171  290649
# 404268  404268  537909  537910
# 404269  404269  537911  349794
# 404270  404270  537912   35364
# 404271  404271  537913  537914
# 404272  404272  128018   14005
# 404273  404273  537915  537916
# 404274  404274  178643   87385
# 404275  404275   97922  537917
# 404276  404276   24305  308365
# 404277  404277  355668  537918
# 404278  404278  537919  169786
# 404279  404279  537920  537921
# 404280  404280  537922  537923
# 404281  404281   99131   81495
# 404282  404282    1931   16773
# 404283  404283  537924  537925
# 404284  404284  537926  537927
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# 5       Astrology: I am a Capricorn Sun Cap moon and c...
# 6                                     Should I buy tiago?
# 7                          How can I be a good geologist?
# 8                         When do you use シ instead of し?
# 9       Motorola (company): Can I hack my Charter Moto...
# 10      Method to find separation of slits using fresn...
# 11            How do I read and find my YouTube comments?
# 12                   What can make Physics easy to learn?
# 13            What was your first sexual experience like?
# 14      What are the laws to change your status from a...
# 15      What would a Trump presidency mean for current...
# 16                           What does manipulation mean?
# 17      Why do girls want to be friends with the guy t...
# 18      Why are so many Quora users posting questions ...
# 19      Which is the best digital marketing institutio...
# 20                             Why do rockets look white?
# 21                  What's causing someone to be jealous?
# 22        What are the questions should not ask on Quora?
# 23                               How much is 30 kV in HP?
# 24      What does it mean that every time I look at th...
# 25      What are some tips on making it through the jo...
# 26                               What is web application?
# 27      Does society place too much importance on sports?
# 28                 What is best way to make money online?
# 29                 How should I prepare for CA final law?
# ...                                                   ...
# 404260                   Which phone is best under 12000?
# 404261  Who is the overall most popular Game of Throne...
# 404262          How do you troubleshoot a Toshiba laptop?
# 404263  How does the burning of fossil fuels contribut...
# 404264  Is it safe to store an external battery power ...
# 404265                  How can I gain weight on my body?
# 404266  What is the green dot next to the phone icon o...
# 404267  What are the causes of the fall of the Roman E...
# 404268  Why don't we still do great music like in the ...
# 404269  How do you diagnose antisocial personality dis...
# 404270        What is the difference between who and how?
# 404271  Does Stalin have any grandchildren that are st...
# 404272  What are the best new car products or inventio...
# 404273    What happens if you put milk in a coffee maker?
# 404274  Will the next generation of parenting change o...
# 404275  In accounting, why do we debit expenses and cr...
# 404276                         What is copilotsearch.com?
# 404277                            What does analytics do?
# 404278          How did you prepare for AIIMS/NEET/AIPMT?
# 404279  What is the minimum time required to build a f...
# 404280  What are some outfit ideas to wear to a frat p...
# 404281  Why is Manaphy childish in Pokémon Ranger and ...
# 404282        How does a long distance relationship work?
# 404283  What do you think of the removal of the MagSaf...
# 404284         What does Jainism say about homosexuality?
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# 404287                                  What is one coin?
# 404288  What is the approx annual cost of living while...
# 404289              What is like to have sex with cousin?
#
#                                                 question2  is_duplicate  \
# 0       What is the step by step guide to invest in sh...             0
# 1       What would happen if the Indian government sto...             0
# 2       How can Internet speed be increased by hacking...             0
# 3       Find the remainder when [math]23^{24}[/math] i...             0
# 4                 Which fish would survive in salt water?             0
# 5       I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 6       What keeps childern active and far from phone ...             0
# 7               What should I do to be a great geologist?             1
# 8                   When do you use "&" instead of "and"?             0
# 9       How do I hack Motorola DCX3400 for free internet?             0
# 10      What are some of the things technicians can te...             0
# 11                 How can I see all my Youtube comments?             1
# 12                How can you make physics easy to learn?             1
# 13                 What was your first sexual experience?             1
# 14      What are the laws to change your status from a...             0
# 15      How will a Trump presidency affect the student...             1
# 16                          What does manipulation means?             1
# 17               How do guys feel after rejecting a girl?             0
# 18      Why do people ask Quora questions which can be...             1
# 19      Which is the best digital marketing institute ...             0
# 20            Why are rockets and boosters painted white?             1
# 21       What can I do to avoid being jealous of someone?             0
# 22                  Which question should I ask on Quora?             0
# 23      Where can I find a conversion chart for CC to ...             0
# 24       How many times a day do a clock’s hands overlap?             0
# 25      What are some tips on making it through the jo...             0
# 26                 What is the web application framework?             0
# 27               How do sports contribute to the society?             0
# 28              What is best way to ask for money online?             0
# 29      How one should know that he/she completely pre...             1
# ...                                                   ...           ...
# 404260           What is the best phone to buy below 15k?             0
# 404261  Who is the most popular character in the Game ...             1
# 404262                   How do I reset a Toshiba laptop?             0
# 404263  Why does CO2 contribute more to global warming...             0
# 404264         How do I make a safe and cheap power bank?             0
# 404265                  What should I eat to gain weight?             1
# 404266  My boyfriend says he deleted his Facebook Mess...             0
# 404267  What were the most important causes and effect...             1
# 404268       Should I raise my young child on 80's music?             0
# 404269  What Does It Feel Like to have antisocial pers...             0
# 404270      What is the difference between "&" and "and"?             0
# 404271  What was Joseph Stalin's 5 year plan? How did ...             0
# 404272  What are some mind-blowing vehicles tools that...             1
# 404273  What would happen if I put milk instead of wat...             1
# 404274  What kind of parents will the next generation ...             1
# 404275  What is a utilities expense in accounting? How...             0
# 404276                           What is ContenVania.com?             0
# 404277                   What are analytical people like?             0
# 404278  How did you prepare for the AIIMS UG entrance ...             0
# 404279  What is a cheaper and quicker way to build an ...             0
# 404280  What are some outfit ideas wear to a frat them...             1
# 404281  Why is Manaphy annoying in Pokemon ranger and ...             1
# 404282    How are long distance relationships maintained?             1
# 404283  What will the CPU upgrade to the 2016 Apple Ma...             0
# 404284  What does Jainism say about Gays and Homosexua...             1
# 404285  How many keywords are there in PERL Programmin...             0
# 404286         Is it true that there is life after death?             1
# 404287                                  What's this coin?             0
# 404288  I am having little hairfall problem but I want...             0
# 404289      What is it like to have sex with your cousin?             0
#
#                                                         0  \
# 0       step by step guide invest in share market in I...
# 1                       story Kohinoor Koh i Noor Diamond
# 2       How can I increase speed my internet connectio...
# 3        Why am I mentally very lonely How can I solve it
# 4       one dissolve in water quickly sugar salt metha...
# 5       astrology I am Capricorn Sun Cap moon cap risi...
# 6                                      Should I buy tiago
# 7                             How can I be good geologist
# 8                                 When do you use instead
# 9       Motorola company Can I hack my Charter Motorol...
# 10      method find separation slits using fresnel bip...
# 11                 How do I read find my YouTube comments
# 12                            can make Physics easy learn
# 13                  was your first sexual experience like
# 14      are laws change your status from student visa ...
# 15      would Trump presidency mean current internatio...
# 16                                 does manipulation mean
# 17      Why do girls want be friends with guy they reject
# 18      Why are many Quora users posting questions are...
# 19         best digital marketing institution in Banglore
# 20                              Why do rockets look white
# 21                           s causing someone be jealous
# 22                  are questions should not ask on Quora
# 23                                   How much 30 kV in HP
# 24      does it mean every time I look at clock number...
# 25      are some tips on making it job interview proce...
# 26                                        web application
# 27       Does society place too much importance on sports
# 28                             best way make money online
# 29                      How should I prepare CA final law
# ...                                                   ...
# 404260                             phone best under 12000
# 404261    Who overall most popular Game Thrones character
# 404262             How do you troubleshoot Toshiba laptop
# 404263  How does burning fossil fuels contribute globa...
# 404264  it safe store external battery power bank USB ...
# 404265                   How can I gain weight on my body
# 404266             green dot next phone icon on messenger
# 404267                       are causes fall Roman Empire
# 404268  Why don t we still do great music like in 70 s...
# 404269  How do you diagnose antisocial personality dis...
# 404270                         difference between who how
# 404271  Does Stalin have any grandchildren are still a...
# 404272  are best new car products inventions most peop...
# 404273               happens you put milk in coffee maker
# 404274    Will next generation parenting change stay same
# 404275  In accounting why do we debit expenses credit ...
# 404276                                  copilotsearch com
# 404277                                  does analytics do
# 404278               How did you prepare AIIMS NEET AIPMT
# 404279            minimum time required build flyover 1km
# 404280              are some outfit ideas wear frat party
# 404281  Why Manaphy childish in Pok mon Ranger Temple Sea
# 404282           How does long distance relationship work
# 404283  do you think removal MagSafe connector from Ap...
# 404284                     does Jainism say homosexuality
# 404285  How many keywords are there in Racket programm...
# 404286              Do you believe there life after death
# 404287                                           one coin
# 404288  approx annual cost living studying in UIC Chic...
# 404289                          like have sex with cousin
#
#                                                         0  \
# 0               step by step guide invest in share market
# 1       would happen Indian government stole Kohinoor ...
# 2       How can Internet speed be increased by hacking...
# 3       find remainder when math 23 24 math divided by...
# 4                        fish would survive in salt water
# 5       I am triple Capricorn Sun Moon ascendant in Ca...
# 6        keeps childern active far from phone video games
# 7                          should I do be great geologist
# 8                                 When do you use instead
# 9            How do I hack Motorola DCX3400 free internet
# 10      are some things technicians can tell durabilit...
# 11                  How can I see all my Youtube comments
# 12                    How can you make physics easy learn
# 13                       was your first sexual experience
# 14      are laws change your status from student visa ...
# 15      How will Trump presidency affect students pres...
# 16                                does manipulation means
# 17                  How do guys feel after rejecting girl
# 18      Why do people ask Quora questions can be answe...
# 19               best digital marketing institute in Pune
# 20                 Why are rockets boosters painted white
# 21                   can I do avoid being jealous someone
# 22                         question should I ask on Quora
# 23        Where can I find conversion chart CC horsepower
# 24            How many times day do clock s hands overlap
# 25      are some tips on making it job interview proce...
# 26                              web application framework
# 27                       How do sports contribute society
# 28                              best way ask money online
# 29      How one should know he she completely prepare ...
# ...                                                   ...
# 404260                           best phone buy below 15k
# 404261  Who most popular character in Game Thrones series
# 404262                      How do I reset Toshiba laptop
# 404263  Why does CO2 contribute more global warming wa...
# 404264                How do I make safe cheap power bank
# 404265                           should I eat gain weight
# 404266  My boyfriend says he deleted his Facebook Mess...
# 404267  were most important causes effects fall Roman ...
# 404268        Should I raise my young child on 80 s music
# 404269  Does It Feel Like have antisocial personality ...
# 404270                                 difference between
# 404271  was Joseph Stalin s 5 year plan How did they a...
# 404272  are some mind blowing vehicles tools exist mos...
# 404273  would happen I put milk instead water in my au...
# 404274             kind parents will next generation have
# 404275  utilities expense in accounting How do you acc...
# 404276                                    ContenVania com
# 404277                         are analytical people like
# 404278        How did you prepare AIIMS UG entrance exams
# 404279    cheaper quicker way build underpass flyover why
# 404280       are some outfit ideas wear frat themed party
# 404281  Why Manaphy annoying in Pokemon ranger temple sea
# 404282     How are long distance relationships maintained
# 404283       will CPU upgrade 2016 Apple MacBook Pro mean
# 404284                does Jainism say Gays Homosexuality
# 404285  How many keywords are there in PERL Programmin...
# 404286                     it true there life after death
# 404287                                             s coin
# 404288  I am having little hairfall problem I want use...
# 404289                  it like have sex with your cousin
#
#                                                         0  \
# 0       step by step guide invest in share market in I...
# 1                       story Kohinoor Koh i Noor Diamond
# 2       How can I increase speed my internet connectio...
# 3        Why am I mentally very lonely How can I solve it
# 4       one dissolve in water quickly sugar salt metha...
# 5       astrology I am Capricorn Sun Cap moon cap risi...
# 6                                      Should I buy tiago
# 7                             How can I be good geologist
# 8                                 When do you use instead
# 9       Motorola company Can I hack my Charter Motorol...
# 10      method find separation slits using fresnel bip...
# 11                 How do I read find my YouTube comments
# 12                            can make Physics easy learn
# 13                  was your first sexual experience like
# 14      are laws change your status from student visa ...
# 15      would Trump presidency mean current internatio...
# 16                                 does manipulation mean
# 17      Why do girls want be friends with guy they reject
# 18      Why are many Quora users posting questions are...
# 19         best digital marketing institution in Banglore
# 20                              Why do rockets look white
# 21                           s causing someone be jealous
# 22                  are questions should not ask on Quora
# 23                                   How much 30 kV in HP
# 24      does it mean every time I look at clock number...
# 25      are some tips on making it job interview proce...
# 26                                        web application
# 27       Does society place too much importance on sports
# 28                             best way make money online
# 29                      How should I prepare CA final law
# ...                                                   ...
# 404260                             phone best under 12000
# 404261    Who overall most popular Game Thrones character
# 404262             How do you troubleshoot Toshiba laptop
# 404263  How does burning fossil fuels contribute globa...
# 404264  it safe store external battery power bank USB ...
# 404265                   How can I gain weight on my body
# 404266             green dot next phone icon on messenger
# 404267                       are causes fall Roman Empire
# 404268  Why don t we still do great music like in 70 s...
# 404269  How do you diagnose antisocial personality dis...
# 404270                         difference between who how
# 404271  Does Stalin have any grandchildren are still a...
# 404272  are best new car products inventions most peop...
# 404273               happens you put milk in coffee maker
# 404274    Will next generation parenting change stay same
# 404275  In accounting why do we debit expenses credit ...
# 404276                                  copilotsearch com
# 404277                                  does analytics do
# 404278               How did you prepare AIIMS NEET AIPMT
# 404279            minimum time required build flyover 1km
# 404280              are some outfit ideas wear frat party
# 404281  Why Manaphy childish in Pok mon Ranger Temple Sea
# 404282           How does long distance relationship work
# 404283  do you think removal MagSafe connector from Ap...
# 404284                     does Jainism say homosexuality
# 404285  How many keywords are there in Racket programm...
# 404286              Do you believe there life after death
# 404287                                           one coin
# 404288  approx annual cost living studying in UIC Chic...
# 404289                          like have sex with cousin
#
#                                                         0
# 0               step by step guide invest in share market
# 1       would happen Indian government stole Kohinoor ...
# 2       How can Internet speed be increased by hacking...
# 3       find remainder when math 23 24 math divided by...
# 4                        fish would survive in salt water
# 5       I am triple Capricorn Sun Moon ascendant in Ca...
# 6        keeps childern active far from phone video games
# 7                          should I do be great geologist
# 8                                 When do you use instead
# 9            How do I hack Motorola DCX3400 free internet
# 10      are some things technicians can tell durabilit...
# 11                  How can I see all my Youtube comments
# 12                    How can you make physics easy learn
# 13                       was your first sexual experience
# 14      are laws change your status from student visa ...
# 15      How will Trump presidency affect students pres...
# 16                                does manipulation means
# 17                  How do guys feel after rejecting girl
# 18      Why do people ask Quora questions can be answe...
# 19               best digital marketing institute in Pune
# 20                 Why are rockets boosters painted white
# 21                   can I do avoid being jealous someone
# 22                         question should I ask on Quora
# 23        Where can I find conversion chart CC horsepower
# 24            How many times day do clock s hands overlap
# 25      are some tips on making it job interview proce...
# 26                              web application framework
# 27                       How do sports contribute society
# 28                              best way ask money online
# 29      How one should know he she completely prepare ...
# ...                                                   ...
# 404260                           best phone buy below 15k
# 404261  Who most popular character in Game Thrones series
# 404262                      How do I reset Toshiba laptop
# 404263  Why does CO2 contribute more global warming wa...
# 404264                How do I make safe cheap power bank
# 404265                           should I eat gain weight
# 404266  My boyfriend says he deleted his Facebook Mess...
# 404267  were most important causes effects fall Roman ...
# 404268        Should I raise my young child on 80 s music
# 404269  Does It Feel Like have antisocial personality ...
# 404270                                 difference between
# 404271  was Joseph Stalin s 5 year plan How did they a...
# 404272  are some mind blowing vehicles tools exist mos...
# 404273  would happen I put milk instead water in my au...
# 404274             kind parents will next generation have
# 404275  utilities expense in accounting How do you acc...
# 404276                                    ContenVania com
# 404277                         are analytical people like
# 404278        How did you prepare AIIMS UG entrance exams
# 404279    cheaper quicker way build underpass flyover why
# 404280       are some outfit ideas wear frat themed party
# 404281  Why Manaphy annoying in Pokemon ranger temple sea
# 404282     How are long distance relationships maintained
# 404283       will CPU upgrade 2016 Apple MacBook Pro mean
# 404284                does Jainism say Gays Homosexuality
# 404285  How many keywords are there in PERL Programmin...
# 404286                     it true there life after death
# 404287                                             s coin
# 404288  I am having little hairfall problem I want use...
# 404289                  it like have sex with your cousin
#
# [404290 rows x 10 columns]
